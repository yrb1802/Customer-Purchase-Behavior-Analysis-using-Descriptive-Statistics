# %% [markdown]
# <a href="https://colab.research.google.com/github/yrb1802/Customer-Purchase-Behavior-Analysis-using-Descriptive-Statistics/blob/main/Mid_course_Statistics_Project_Yashraj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# **Name:** Yashraj Belchandan

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
# import libaray for data preprocessing
import pandas as pd
import numpy as np

# import library for data visualisation
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#mount the drive to the notebook
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing the dataset from the drive
df = pd.read_csv("/content/drive/MyDrive/Superstore Marketing Data - Sheet1.csv")

# %%
# Dataset First Look
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# Dataset information(all column names and datatypes)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Rows and column in dataset
print(f"The number of rows are {df.shape[0]} and number of coloumns are {df.shape[1]}")
# Out:
# The number of rows are 2240 and number of coloumns are 22

# %%
# Check duplicated values
print(f"The count of duplicated values are {df.duplicated().sum()}")
# Out:
# The count of duplicated values are 0

# %%
# Check any null values are there
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# Impute missing values with the mean
income_mean = df['Income'].mean()
df['Income'].fillna(income_mean, inplace=True)
# Out:
# <ipython-input-36-96b117c93080>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(income_mean, inplace=True)

# %%
# drop column that is not required
df.drop(['Id','Dt_Customer'], axis=1, inplace=True)

# %% [markdown]
# Insight and manipulations done
#
#
# 1) There are 2240 rows and 20 columns.
#
# 2) Data types are integer, object and float.
#
# 3) Drop columns -Id, Dt_Customer as they are not required in the data analysis.
#
# 4) No duplicates found
#
# 5) Null value is found in income column , Filling it with mean as count is low.

# %%
# age distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Year_Birth'], bins=20, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
# education distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Education', order=df['Education'].value_counts().index, hue='Education', palette='viridis', dodge=False, legend=False)

plt.title('Education Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
# marital status distribution
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Marital_Status', order=df['Marital_Status'].value_counts().index, hue='Marital_Status', palette='viridis', dodge=False, legend=False)
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Summary of Basic Statistics:
# Distribution of data among Year_Birth, education and marital status.
#
# 1) Mostly year birth 1960- 1980 are the customers.
#
# 2) Graduation number is high.
#
# 3) Married couples do more shopping.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
# Descriptive statististics using describe method
df.describe()
# Out:
#         Year_Birth         Income      Kidhome     Teenhome      Recency  \
# count  2240.000000    2240.000000  2240.000000  2240.000000  2240.000000
# mean   1968.805804   52247.251354     0.444196     0.506250    49.109375
# std      11.984069   25037.797168     0.538398     0.544538    28.962453
# min    1893.000000    1730.000000     0.000000     0.000000     0.000000
# 25%    1959.000000   35538.750000     0.000000     0.000000    24.000000
# 50%    1970.000000   51741.500000     0.000000     0.000000    49.000000
# 75%    1977.000000   68289.750000     1.000000     1.000000    74.000000
# max    1996.000000  666666.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
# Calculate Measures of Central Tendency and Dispersion
from scipy.stats import mode

# Selecting key numerical variables
key_var = ['Income', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']

stat = pd.DataFrame(index=key_var)
stat['Mean'] = df[key_var].mean()
stat['Mode'] = df[key_var].mode().iloc[0]
stat['Median'] = df[key_var].median()
stat['Standard Deviation'] = df[key_var].std()
stat['Variance'] = df[key_var].var()

print(stat)
# Out:
#                              Mean          Mode   Median  Standard Deviation  \
# Income               52247.251354  52247.251354  51741.5        25037.797168
# NumDealsPurchases        2.325000      1.000000      2.0            1.932238
# NumCatalogPurchases      2.662054      0.000000      2.0            2.923101
# NumStorePurchases        5.790179      3.000000      5.0            3.250958
# NumWebPurchases          4.084821      2.000000      4.0            2.778714
# NumWebVisitsMonth        5.316518      7.000000      6.0            2.426645
# Recency                 49.109375     56.000000     49.0           28.962453
#
#                          Variance
# Income               6.268913e+08
# NumDealsPurchases    3.733542e+00
# NumCatalogPurchases  8.544517e+00
# NumStorePurchases    1.056873e+01
# NumWebPurchases      7.721252e+00
# NumWebVisitsMonth    5.888606e+00
# Recency              8.388237e+02

# %%
# identify and remove outlier

# Calculate quartiles and IQR for each variable
Q1 = df[key_var].quantile(0.25)
Q3 = df[key_var].quantile(0.75)
IQR = Q3 - Q1

# Determine outliers using IQR method
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df[key_var] < lower_bound) | (df[key_var] > upper_bound)

# Print columns with outliers
columns_with_outliers = outliers.any()
print("Columns with outliers:")
print(columns_with_outliers[columns_with_outliers].index.tolist())

# Remove outliers
df_no_outliers = df[~outliers.any(axis=1)]

# Print summary after removing outliers
print("\nDataset shape before removing outliers:", df.shape)
print("Dataset shape after removing outliers:", df_no_outliers.shape)
# Out:
# Columns with outliers:
# ['Income', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumWebPurchases', 'NumWebVisitsMonth']
#
# Dataset shape before removing outliers: (2240, 20)
# Dataset shape after removing outliers: (2121, 20)

# %%
# after handling outliers
print("\nAfter handling outliers:")

# Calculate Measures of Central Tendency and Dispersion
stat = pd.DataFrame(index=key_var)
stat['Mean'] = df[key_var].mean()
stat['Mode'] = df[key_var].mode().iloc[0]
stat['Median'] = df[key_var].median()
stat['Standard Deviation'] = df[key_var].std()
stat['Variance'] = df[key_var].var()
print(stat)
# Out:
# After handling outliers:
#                              Mean          Mode   Median  Standard Deviation  \
# Income               52247.251354  52247.251354  51741.5        25037.797168
# NumDealsPurchases        2.325000      1.000000      2.0            1.932238
# NumCatalogPurchases      2.662054      0.000000      2.0            2.923101
# NumStorePurchases        5.790179      3.000000      5.0            3.250958
# NumWebPurchases          4.084821      2.000000      4.0            2.778714
# NumWebVisitsMonth        5.316518      7.000000      6.0            2.426645
# Recency                 49.109375     56.000000     49.0           28.962453
#
#                          Variance
# Income               6.268913e+08
# NumDealsPurchases    3.733542e+00
# NumCatalogPurchases  8.544517e+00
# NumStorePurchases    1.056873e+01
# NumWebPurchases      7.721252e+00
# NumWebVisitsMonth    5.888606e+00
# Recency              8.388237e+02

# %% [markdown]
# Used IQR (Interquartile range) for handling outliers
#
# Then again found central tendency and measure of dispersion after removing outliers

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# Binomial Distribution:
#
# Complain:
#
# The Complain variable represents whether a customer complained in the last 2 years (1 if complained, 0 otherwise).
#
# Response:
#
# The Response variable represents whether a customer accepted the offer in the last campaign (1 if accepted, 0 otherwise).

# %%
# Probability and expected value of complain
prob_complain = df['Complain'].mean()
expected_complainers = len(df) * prob_complain
print(f"Probability of a customer complaining: {round(prob_complain,2)}")
print(f"Expected number of complainers: {expected_complainers}")

# Probability and expected value of response
prob_response = df['Response'].mean()
expected_responders = len(df) * prob_response
print(f"Probability of a customer responding: {round(prob_response,2)}")
print(f"Expected number of responders: {expected_responders}")
# Out:
# Probability of a customer complaining: 0.01
# Expected number of complainers: 21.0
# Probability of a customer responding: 0.15
# Expected number of responders: 334.0

# %% [markdown]
# Normal Distribution:

# %% [markdown]
# Income: Yearly household income of customers.
#
# MntWines: Amount spent on wine products in the last 2 years.
#
# MntMeatProducts: Amount spent on meat products in the last 2 years.
#
# MntGoldProds: Amount spent on gold products in the last 2 years.

# %%
from scipy.stats import norm
# Define the variables of interest
var_ = ['Income', 'MntWines', 'MntMeatProducts', 'MntGoldProds']

# Loop through each variable
for var in var_:
  # Calculate mean and standard deviation
  mean_var = df[var].mean()
  std_dev_var = df[var].std()
  normal_dist = norm(mean_var, std_dev_var)

  # Calculate the probability of a specific condition (e.g., above mean)
  probability_above_mean = 1 - normal_dist.cdf(mean_var)

  # Calculate the expected value
  expected_value = normal_dist.mean()

  # Print the results for the variable
  print(f"{var}:")
  print(f"  Probability of {var} above its mean: {probability_above_mean:.4f}")
  print(f"  Expected {var}: {expected_value:.2f}\n")
# Out:
# Income:
#   Probability of Income above its mean: 0.5000
#   Expected Income: 52247.25
#
# MntWines:
#   Probability of MntWines above its mean: 0.5000
#   Expected MntWines: 303.94
#
# MntMeatProducts:
#   Probability of MntMeatProducts above its mean: 0.5000
#   Expected MntMeatProducts: 166.95
#
# MntGoldProds:
#   Probability of MntGoldProds above its mean: 0.5000
#   Expected MntGoldProds: 44.02

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# create new column age
df['Age'] = 2024 - df['Year_Birth']

# Convert categorical variables to numeric
df['Education'] = pd.factorize(df['Education'])[0]
df['Marital_Status'] = pd.factorize(df['Marital_Status'])[0]

# Calculate 'Total_Spending' by summing up various spending columns
df['Total_Spending'] = df['MntFishProducts'] + df['MntMeatProducts'] + df['MntFruits'] + df['MntSweetProducts'] + df['MntWines'] + df['MntGoldProds']

# Select relevant features for segmentation
features = ['Age', 'Income', 'Total_Spending', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']

# Standardize features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features])

# Clustering (K-means)
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(df_scaled)

# Visualize cluster characteristics
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Total_Spending', hue='Cluster', palette='viridis', s=100, alpha=0.8)
plt.title('Customer Segmentation based on Age vs Total Spending')
plt.xlabel('Age')
plt.ylabel('Total Spending')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# Correlation matrix
corr_matrix = df[features].corr()
plt.figure(figsize=(10,6 ))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Customer Segmentation based on Age and Total Spending:
#
# Key insight:

# %% [markdown]
# **Cluster Analysis and Spending Patterns**
#
# - **Cluster 0 (Purple):** Shows low total spending across all age groups, likely indicating low-value or less engaged customers.
#
# - **Cluster 1 (Blue):** Features high total spending, primarily from customers aged 30-70, suggesting core, consistently purchasing customers.
#
# - **Cluster 2 (Green):** Represents younger customers with low spending who may become high-value customers in the future.
#
# - **Cluster 3 (Yellow):** Displays moderate spending across various ages, likely representing occasional shoppers.
#
# - **High Spenders:** Primarily in Cluster 1 (Blue), with spending over 1500, ages 30-70.
#
# - **Low Spenders:** Mostly found in Cluster 0 (Purple), with spending below 500.
#
# - **Outliers:** A few customers with unusually high spending spread across different clusters.

# %% [markdown]
# Age has a positive correlation with income, suggesting that older individuals generally have higher earnings.
#
# Income is strongly correlated with total spending, catalog purchases, and in-store purchases, indicating that higher income levels lead to increased spending and more purchases through catalogs and in stores.
#
# Additionally, total spending is positively correlated with web purchases but negatively correlated with website visits, implying that higher spenders tend to visit the website less frequently.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
import matplotlib.gridspec as gridspec

# Create a 2x2 grid for subplots with equal sizes

fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1], height_ratios=[1, 1])

# Income Distribution
ax0 = plt.subplot(gs[0])
sns.histplot(df['Income'], bins=20, kde=True)
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Income Distribution')

# Relationship Analysis: Income vs. Spending on Wines
ax1 = plt.subplot(gs[1])
sns.scatterplot(data=df, x='Income', y='MntWines', hue='Cluster', palette='Set1', alpha=0.6)
plt.xlabel('Income')
plt.ylabel('Amount spent on Wines')
plt.title('Customer Segmentation based on Income and Wine Spending')
plt.legend(title='Cluster')

# Relationship Analysis: Income vs. Spending on Meat
ax2 = plt.subplot(gs[2])
sns.scatterplot(data=df, x='Income', y='MntMeatProducts', hue='Cluster', palette='Set1', alpha=0.6)
plt.xlabel('Income')
plt.ylabel('Amount spent on Meat Products')
plt.title('Income vs. Meat Spending')

# Relationship Analysis: Income vs. Spending on Fruits
ax3 = plt.subplot(gs[3])
sns.scatterplot(data=df, x='Income', y='MntFruits', hue='Cluster', palette='Set1', alpha=0.6)
plt.xlabel('Income')
plt.ylabel('Amount spent on Fruits')
plt.title('Income vs. Fruits Spending')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Overall Key Insights:**
#
# 1) **Income Distribution:**
#    Most customers have an income below $100,000, with a few high-income outliers.
#
# 2) **Income vs. Spending by Category:**
#    - There is a positive correlation between income and spending on both meat and fruit, indicating that spending on these items increases with higher income.
#    - Customers tend to allocate a greater proportion of their income to meat compared to fruit as income rises.
#    - Higher-income individuals also spend more on wine and meat products, highlighting the influence of disposable income on purchasing behavior.
#
# 3) **Age Distribution:**
#    The majority of customers were born between 1950 and 1980, corresponding to an age range of about 40 to 70 years.
#
# 4) **Education Distribution:**
#    Most customers have completed a graduation-level education, with over 1,000 individuals in this category, followed by those with PhDs, and then Master's degree holders.
#
# 5) **Marital Status Distribution:**
#    - The largest group of customers is married, followed by those living together (indicated as “Together”) and single individuals.
#    - There is a smaller but notable number of divorced customers, while widowed individuals form a minor segment.
#    - The categories "Alone," "YOLO," and "Absurd" represent very few customers, suggesting these are rare or possibly outlier classifications.

# %% [markdown]
# **Recommendations:**
#
# 1) Target high-income clusters with premium meat and wine promotions. Implement loyalty programs and exclusive discounts to enhance retention among these high-spending customers.
#
# 2) Develop tailored marketing strategies for different income groups: offer luxury packages for high-income customers and budget-friendly options for those with lower incomes.
#
# 3) Since the largest segments are married customers and those living together, focus marketing campaigns on family-oriented products and services.
#
# 4) For customers with higher education levels (Graduation, PhD, Master’s), provide in-depth, informative content that aligns with their educational backgrounds. Use technical language and advanced concepts where appropriate to engage this audience effectively.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
